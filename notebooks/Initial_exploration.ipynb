# %% [markdown]
# # Initial Exploration Notebook (Placeholder)
# In this notebook we will have our early data loading, inspection, and cleaning steps.
# We will complete the rest of the data and exploration work during the next milestone, but this is what we started with.

# %% [markdown]
# **Imports**

# %%
import pandas as pd

# %% [markdown]
# **Load Datasets**

# %%
imdb = pd.read_csv('../data/raw/movie_metadata.csv')
box = pd.read_csv('../data/raw/enhanced_box_office_data(2000-2024)u.csv')
imdb.head(), box.head()

# %% [markdown]
# **Info**

# %%
imdb.info()

# %% [markdown]
# **Summary Stats**

# %%
imdb.describe()

# %% [markdown]
# **Missing Values**

# %%
imdb.isna().sum().sort_values(ascending=False).head(10)

# %% [markdown]
# **Simple Cleaning (Exploration)**

# %%
if 'movie_title' in imdb.columns:
    imdb['title_clean'] = imdb['movie_title'].str.lower().str.strip()
    imdb[['movie_title', 'title_clean']].head()
else:
    imdb.head()
